# %%
# quotes 
print("Python Programming")
# Out:
# Python Programming

# %%
print("hi, i am pratyush!")
# Out:
# hi, i am pratyush!

# %%
print('pratyush')
# Out:
# pratyush

# %%
'pra\ntyush'
# Out:
# 'pra\ntyush'

# %%
input("what is your name?")
# Out:
# what is your name?pratyush
# 'pratyush'

# %%
# what is variable?
# storage or warehouse where u can put things

name = "pratyush"
age = 28
place = "noida"

# %%
print(name,'\nshgfdfghfghdghdghdu',age,'\n',place)
# Out:
# pratyush
# shgfdfghfghdghdghdu 28
#  noida

# %%
print("name: ",name,"\nage: ",age,"\nplace: ",place)
# Out:
# name:  pratyush
# age:  28
# place:  noida

# %%
name
# Out:
# 'pratyush'

# %%
_python = 'abcd'

# %%
name = "pratyush"
print(Name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b39238de9e05> in <module>
#       1 name = "pratyush"
# ----> 2 print(Name)
#
# NameError: name 'Name' is not defined
