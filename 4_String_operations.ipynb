# %%
print('''Twinkle Twinkle little star
How I wonder what''')
# Out:
# Twinkle Twinkle little star
# How I wonder what

# %%
name = "pratyush"

print(name, type(name))
# Out:
# pratyush <class 'str'>

# %%
dialogue = 'Rani said,\'something is there in the house.\''
comment = '\\Data science is trending field\\'

# %%
print(dialogue)
# Out:
# Rani said,'something is there in the house.'

# %%
print(comment)
# Out:
# \Data science is trending field\

# %% [markdown]
# # **String Indexing**

# %%
# Text Book without Index 
# Text Book with Index - much more efficient 

# Indexing - Fetching value from particular location 

# Syntax of Indexing:
#       String[index]

# Python has buit in indexes, Indexes start from 0 in python

# %%
name = "Chanchal"

# %%
name[3]
# Out:
# 'n'

# %%
name[4]
# Out:
# 'c'

# %%
name[0]
# Out:
# 'C'

# %%
line = "gfdyjtfukfdthyrsdthjfjkhsrhrfuhfvhtdtfhmcthfj,fthjdfyhvhjmjfuk"

line[-1]
# Out:
# 'k'

# %%
# Q. fetch the 4th character in the string

S = "india"

# %%
S[3]
# Out:
# 'i'

# %%
A = "fabulous"

A[4]
# Out:
# 'l'

# %%
A[-4]
# Out:
# 'l'

# %%
# String Slicing 
# Feching the subset of whole string 

# slice a cake -> cake ! 
# slice a string -> string ! 
# slice a datatype -> datatype !

# Syntax of Slicing 
# string[start_index:end_index]
# start_index -> inclusive, end_index -> exclusive 

# if you're slicing from first character - need not mention to start_index 
# if you're slicing till end character - need not mention to end_index 

# name = sachin , fetch from 2nd character to 4rth 
#        012345
# name[1:3] -> I'll srtart at 1st index and fetch 1st and 2nd index

# %%
A[:5]
# Out:
# 'fabul'

# %%
name[:4] # include 0, 1, 2, 3
# Out:
# 'Chan'

# %%
name = 'priya srivastav'

name[::3]  # string [start : end : step]    by default :- string[0 : length : 1]
# Out:
# 'pysvt'

# %%
name = 'Pratyush'

name[1::2]
# Out:
# 'rtuh'

# %%
# Interviewer : fetch from 2nd character to 4rth 
# You : is 4rth character inclusive or exclusive ?
# Interviewer : exclusive
name = 'pratyush'
print(name[1:3])
# Out:
# ra

# %%
# Interviewer : fetch from 2nd character to 4rth 
# You : is 4rth character inclusive or exclusive ?
# Interviewer : inclusive
name = 'pratyush'
print(name[1:4])
# Out:
# rat

# %%
# fetch only sachin

name = 'sachin tendulkar'
print(name[:6])
# Out:
# sachin

# %%
print("sachin "*5)
# Out:
# sachin sachin sachin sachin sachin

# %%
name = "chanchal"

len(name)
# Out:
# 8

# %%
name = "priya"

len(name)
# Out:
# 5

# %%
# immutable - u can not change any particular character within
# u can change whole string

# s1 = 'pratyush'
# s1[3] = 'q'
# s1

# %%
string1 = "How are you?"
string2 = "fine"

# concatenate property

join = string1 + string2
print(join)
# Out:
# How are you?fine

# %%
# replicate string

print("sachin "*5)
# Out:
# sachin sachin sachin sachin sachin

# %%
name = "chanchal"

print("p" in name)
print("c" in name)
# Out:
# False
# True

# %%
# built in functions

msg = "workisworship"

print(len(msg))
# Out:
# 13

# %%
print(max(msg))
# Out:
# w

# %%
print(min(msg))
# Out:
# h

# %%
# string methods -type and address

# * , &

s = "Afternoon"

print(type(s))
print(id(s))
# Out:
# <class 'str'>
# 140579239057328

# %%
import random 

print(random.randint(1,5))
# Out:
# 2

# %%
name = "chanchal"

print(name.upper())
# Out:
# CHANCHAL

# %%
name = "PRIYA"

print(name.lower())
# Out:
# priya

# %%
name = "prAtYUsh"

print(name.capitalize())
# Out:
# Pratyush

# %%
# to check whether the string contains number or alphabets or other methods

s = "Pratyush"

print(s.isalpha())
# Out:
# True

# %%
print(s.isdigit())
# Out:
# False

# %%
print(s.isalnum())
# Out:
# True

# %%
print(s.islower())
# Out:
# False

# %%
print(s.isupper())
# Out:
# False

# %%
print(s.startswith('P'))
# Out:
# True

# %%
print(s.endswith('s'))
# Out:
# False

# %%
# find() and replace()

a = "Happy New Year 2023"

print(a.find('N'))
# Out:
# 6

# %%
# syntex - string.find('chr', start_index, end_index)
print(a.find('a',2,13))
# Out:
# 12

# %%
print(a.replace('3', '6'))
# Out:
# Happy New Year 2026

# %%
# trims whitespace - lstrip( ), rstrip( ), strip( )

password = "-----pratyush----"

print(password.lstrip('-'))
# Out:
# pratyush----

# %%
print(password.rstrip('-'))
# Out:
# -----pratyush

# %%
print(password.strip('-'))
# Out:
# pratyush

# %%
# split and partition

s = "Where there is a will, there is a way"

print(s.split())
# Out:
# ['Where', 'there', 'is', 'a', 'will,', 'there', 'is', 'a', 'way']

# %%
a, b, c, d, e, f, g, h, i = s.split()

# %%
b
# Out:
# 'there'

# %%
x = "Rani is sleeping"

print(x.partition('is'))
# Out:
# ('Rani ', 'is', ' sleeping')

# %%
# join 

s = "Hello"
s678 = list(s)
print('-'.join(s))
print('%'.join(s678))
# Out:
# H-e-l-l-o
# H%e%l%l%o

# %%
# String Conversions

# 1. Converting the case of characters in string

s = "string"

print(s.upper())
# Out:
# STRING

# %%
s= 'STRING'

print(s.lower())
# Out:
# string

# %%
print(s.capitalize())
# Out:
# String

# %%
t = 'Data Science is need of today world'

print(t.title())
# Out:
# Data Science Is Need Of Today World

# %%
s = "pRatyUSh"

print(s.swapcase())
# Out:
# PrATYusH

# %%
# ASCII Table -  built-in function chr( ) and ord( )

print(chr(65))
# Out:
# A

# %%
print(chr(90))
# Out:
# Z

# %%
print(chr(94))
# Out:
# ^

# %%
print(ord('A'))
# Out:
# 65

# %%
print(ord('a'))
# Out:
# 97

# %%
# String Comparison :- ==, !=, <, >, <=, >=

s1 = "Bombay"
s2 = "bombay"
s3 = "Nagpur"
s4 = "Bombaywala"
s5 = "Bombay"

print(s1==s2)
# Out:
# False

# %%
print(s2 >= s1)
# Out:
# True

# %%
print(id(s1) == id(s5))
# Out:
# True

# %%
# search() and count()

s = "chanchal"

print(s.count('h'))
# Out:
# 2

# %%
s1 = 'rear'
s2 = 'rare'

print(s1 == s2, end=' ')
print(set(s1) == set(s2))
# Out:
# False True
