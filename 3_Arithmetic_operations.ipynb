# %% [markdown]
# 1. Addition
# 2. Substraction
# 3. Multiplication
# 4. Division
# 5. floor division
# 6. remainder
# 7. power

# %%
import math
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc']

# %%
print(dir(__builtins__))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EnvironmentError', 'Exception', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 'StopIteration', 'SyntaxError', 'SyntaxWarning', 'SystemErr
# ...

# %%
# Addition 

a, b = 10, 20      # int

a+b
# Out:
# 30

# %%
a, b = 20, 10.0

a+b
# Out:
# 30.0

# %%
a = complex(20,10)
b = 40
a+b
# Out:
# (60+10j)

# %%
# substraction

a, b = 20, 10

a-b
# Out:
# 10

# %%
a, b = 20.0, 10

a-b
# Out:
# 10.0

# %%
# multiplication

a, b = 2, 5

a*b
# Out:
# 10

# %%
a, b = 2.5, 4

a*b
# Out:
# 10.0

# %%
a = complex(2, 4)
b = 2.5
a*b
# Out:
# (5+10j)

# %%
# division

a, b = 20, 10

a/b
# Out:
# 2.0

# %%
int(a/b)
# Out:
# 2

# %%
# floor division - [Divident = Divisor*Quotient + Reminder]

a, b = 121, 10

a//b
# Out:
# 12

# %%
a % b # modulus
# Out:
# 1

# %%
# power - exponential

a, b = 2, 3

a**b
# Out:
# 8

# %%
b**a
# Out:
# 9

# %%
a, b = 2.0, 3

a**b
# Out:
# 8.0

# %%
b**a
# Out:
# 9.0

# %%
round(4.367478577, 3)
# Out:
# 4.367

# %%
import math as m

# %%
a = -5.3

m.floor(a)
# Out:
# -6

# %%
m.ceil(a)
# Out:
# -5

# %%
m.pi
# Out:
# 3.141592653589793

# %%
m.e
# Out:
# 2.718281828459045

# %%
m.sqrt(900)
# Out:
# 30.0

# %%
m.factorial(5)
# Out:
# 120

# %%
abs(-5.3)
# Out:
# 5.3

# %%
abs(-2)
# Out:
# 2

# %%
m.fabs(-2)
# Out:
# 2.0

# %%
abs(complex(4,3))
# Out:
# 5.0

# %%
# m.fabs(complex(4,3)) - give error

# %%
m.degrees(m.asin(0.5))
# Out:
# 30.000000000000004

# %%
m.tan(m.radians(300))
# Out:
# -1.732050807568877

# %%
m.hypot(12,5)
# Out:
# 13.0

# %%
import random as r

int(r.random()*10)
# Out:
# 4

# %%
r.randint(1,100)
# Out:
# 33

# %%
r.seed(10)
print(r.randint(1,100))
print(r.randint(2,56))
# Out:
# 74
# 4

# %%
lst = [17,22,13,8789,67]

s = set(lst)
s
# Out:
# {13, 17, 22, 67, 8789}

# %%
id(lst)
# Out:
# 140170263087360

# %%
chr(97)
# Out:
# 'a'

# %%
chr(65)
# Out:
# 'A'

# %%
ord('A')
# Out:
# 65

# %%
a = 5
b = 5.0
a is b
# Out:
# False
