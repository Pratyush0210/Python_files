# %%
# if 

a = 30
if a<50:
  print("the condition is True")
# Out:
# the condition is True

# %%
if a<10:
  print("the condition is True")

# %%
# if - else 

maths = 30
if maths>35:
  print("Pass")

else:
  print("Fail")
# Out:
# Fail

# %%
# if-elif-else

english = int(input("in between 0-100= "))
computer = int(input("in between 0-100= "))
print()
if english >35 and computer >35:
  print("Pass")

elif english > 35 or computer >35:
  print("Pass in one subject")

else:
  print("Fail")
# Out:
# in between 0-100= 50
# in between 0-100= 70
#
# Pass

# %%
# restaurant menu
hotel = {"Aaloo Tikki": 120,
         "Chicken Biryani": 300,
         "Paneer Dosa": 200,
         "Samosa": 20,
         "Pizza": 150}

if hotel["Chicken Biryani"] <250:
  print("Get me a chicken biryani")
elif hotel["Pizza"] < 150:
  if (150 - hotel["Pizza"]) >= 20:
    print("Get me a pizza and a samosa")
  else:
    print("Get me a pizza")
else:
  print("Get me a paneer dosa")
# Out:
# Get me a paneer dosa

# %%
# problem 5.1 from 
# While purchasing certain items, a discount of 10% is offered if the
# quantity purchased is more than 1000. If quantity and price per item are
# input through the keyboard, write a program to calculate the total
# expenses.

# %%
qty = int(input("Enter the quantity: "))
price = float(input("Enter the price of single item: "))
if qty > 1000:
  dis = 10

else:
  dis = 0

totexp = qty * price * (1- (dis/100))
print(f"The total expense is Rs. {totexp}")
# Out:
# Enter the quantity: 1200
# Enter the price of single item: 10
# The total expense is Rs. 10800.0

# %%
# Problem 5.2
# In a company an employee is paid as under:
# If his basic salary is less than Rs. 1500, then HRA = 10% of basic salary
# and DA = 90% of basic salary. If his salary is either equal to or above Rs.
# 1500, then HRA = Rs. 500 and DA = 98% of basic salary. If the employee's
# salary is input through the keyboard write a program to find his gross
# salary.

# %%
Basic_Salary = float(input("Enter your salary: Rs. "))

if Basic_Salary >= 1500:
  HRA = 500
  DA = 0.98 * Basic_Salary

else:
  HRA = 0.1 * Basic_Salary
  DA = 0.9 * Basic_Salary

print(f"Total Gross Salary= Rs. {Basic_Salary + HRA + DA}")
# Out:
# Enter your salary: Rs. 1600
# Total Gross Salary= Rs. 3668.0

# %% [markdown]
# ### **Problems**

# %%
# [E]
# (a) Any integer is input through the keyboard. Write a program to find
# out whether it is an odd number or even number.

# %%
num = int(input("Enter any number: "))

if num % 2 == 0:      # ==, >, <, >=, <= relational operator
  print("EVEN")

else:
  print("ODD")
# Out:
# Enter any number: 56
# EVEN

# %%
# (c) If ages of Ram, Shyam and Ajay are input through the keyboard,
# write a program to determine the youngest of the three.

# %%
Ram = int(input("Age of Ram: "))
Shyam = int(input("Age of Shyam: "))
Ajay = int(input("Age of Ajay: "))

if Ram < Shyam:
  if Ram < Ajay:
    print("\nRam is youngest")

else:
  if Shyam < Ajay:
    print("\nShyam is youngest")
  else:
    print("\nAjay is youngest")
# Out:
# Age of Ram: 60
# Age of Shyam: 30
# Age of Ajay: 40
#
# Shyam is youngest

# %%
# (d) Write a program to check whether a triangle is valid or not, when
# the three angles of the triangle are entered through the keyboard.
# A triangle is valid if the sum of all the three angles is equal to 180 degrees.

# %%
A = int(input("Angle: "))
B = int(input("Angle: "))
C = int(input("Angle: "))

if A+B+C == 180:
  print("\nIt is valid Triangle")
else:
  print("\nNot valid")
# Out:
# Angle: 40
# Angle: 80
# Angle: 20
#
# Not valid

# %%
# If the three sides of a triangle are entered through the keyboard,
# write a program to check whether the triangle is isosceles,
# equilateral,scalene or right angled triangle.

# %%
a = int(input())
b = int(input())
c = int(input())

if a+b > c and b+c > a and a+c > b:
  if a==b==c :
    print("Equilateral Triangle")

  elif a==b or b==c or a==c:
    print("Isosceles Triangle")

  elif a**2 + b**2 == c**2 or a**2 + c**2 == b**2 or b**2 + c**2 == a**2:
    print("Right Angled Triangle")

  else:
    print("Scalene Triangle")
else:
  print("Triangle is not valid")
# Out:
# 20
# 30
# 30
# Isosceles Triangle

# %%
# (g) Given three points (x1, y1), (x2, y2) and (x3, y3), write a program to
# check if all the three pointsfall on one straight line.
